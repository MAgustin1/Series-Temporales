# %% [markdown]
# # Trabajo Práctico Final Series Temporales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.ticker import IndexLocator
import seaborn as sns

# %%
df1 = pd.read_csv('desempleo de usa.csv')

# %%
df1.head()
# Out:
#          DATE  UNRATE
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5

# %%
df1['DATE'].min(), df1['DATE'].max(),df1['UNRATE'].min(), df1['UNRATE'].max()
# Out:
# ('1948-01-01', '2023-02-01', 2.5, 14.7)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 902 entries, 0 to 901
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    902 non-null    object
#  1   UNRATE  902 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.2+ KB

# %%
df1.describe()
# Out:
#            UNRATE
# count  902.000000
# mean     5.727938
# std      1.704625
# min      2.500000
# 25%      4.400000
# 50%      5.500000
# 75%      6.800000
# max     14.700000

# %%
fig = plt.figure(figsize=(20, 6))
ax = fig.add_subplot(1, 1, 1)
ax.plot(df1["DATE"],df1["UNRATE"],label="Desempleo")
plt.title("Medición del desempleo en USA 1948 - 2023")
plt.xlabel("Fecha")
plt.ylabel("Millones")
plt.yticks(range(2,16,2))


locator = IndexLocator(base=40, offset= 20)
ax.xaxis.set_major_locator(locator)

ax.tick_params(axis='x', labelrotation=45)

plt.legend()
plt.show()

# %%
_,ax1=plt.subplots()
ax1.hist(df1["UNRATE"],bins=30)
# Out:
# (array([ 13.,  15.,  63.,  77.,  73.,  70.,  85., 124.,  94.,  34.,  50.,
#          51.,  49.,  21.,  19.,  19.,  12.,  14.,  10.,   4.,   3.,   0.,
#           0.,   0.,   0.,   0.,   1.,   0.,   0.,   1.]),
#  array([ 2.5       ,  2.90666667,  3.31333333,  3.72      ,  4.12666667,
#          4.53333333,  4.94      ,  5.34666667,  5.75333333,  6.16      ,
#          6.56666667,  6.97333333,  7.38      ,  7.78666667,  8.19333333,
#          8.6       ,  9.00666667,  9.41333333,  9.82      , 10.22666667,
#         10.63333333, 11.04      , 11.44666667, 11.85333333, 12.26      ,
#         12.66666667, 13.07333333, 13.48      , 13.88666667, 14.29333333,
#         14.7       ]),
#  <BarContainer object of 30 artists>)
